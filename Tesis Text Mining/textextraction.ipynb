# %%
#Downloaded libraries: langchain and langchain-community
from langchain.document_loaders import PyPDFLoader

# %%
loader = PyPDFLoader('periodico.pdf')
pages = loader.load()
specific_page = pages[24]
print(specific_page)
# Out:
# page_content='PA NA M Á
# PRÉSTAMOS Y DEPÓSITOS
# AUMENTARON EN 2021
# Los nuevos préstamos totalizaron $16,844 mi-
# llones en 2021, lo cual muestra una señal po-
# sitiva de recuperación económica, detalló.Los préstamos nuevos y
# los depósitos de particu-
# lares en la banca pana-
# meña aumentaron en
# 2021 un 14 % y un 7 .4 %,
# respectivamente, en com-
# paración con 2020, el año
# de la debacle económica,
# informó ayer, la Superin-
# tendencia de Bancos de
# Panamá (SBP).
# El regulador paname-
# ño indicó que el comporta-
# miento positivo de estos
# indicadores se dio en el
# contexto de la reactiva-
# ción económica del país y
# la recuperación del pro-
# ducto interno bruto (PIB)
# en un 15.3 % en el 2021, tras
# registrar en 2020 una caí-
# da del 17.9 % .
# Los nuevos préstamos
# totalizaron $16,844 millo-
# nes en 2021, una señal de
# que la recuperación eco-
# nómica ya empezó a im-
# pactar positivamente a la
# mayoría de los sectores
# productivos, principal-
# mente las actividades co-
# mo del sector agropecua-
# rio, las hipotecas, el consu-
# mo y el comercio, dijo.
# El superintendente de
# bancos, Amauri Castillo,
# llamó a un "optimismo
# prudente" en materia eco-
# nómica y financiera, dada
# la presencia de "múltiples
# riesgos y un marco de fuer-
# te incertidumbre, acre-
# centada por el conflicto en
# Uc ra n i a" .
# El año pasado, los depó-
# sitos de particulares au-
# mentaron $3,328 millones,
# lo que, dijo el regulador,
# "denota la confianza del
# depositante en el Sistema
# Jueve s 10 de m a rzo de 2 02 2
# l ap re n s ag ra f ica .com E conomía 25
# Bancario Nacional".
# El 60 % de los depósitos
# de particulares pertene-
# cen a empresas, donde hu-
# bo una tasa de crecimien-
# to del 6.5 %, mientras que el
# 40 % restante correspon-
# de a personas naturales,
# con alza de 3.8 % respecto
# al 2021, informó.
# Además, informó que
# las cifras de la cartera mo-
# dificada, se redujo en
# $13,681 millones.
# E fe
# economía@laprensagrafica .com' metadata={'producer': 'Adobe PDF Library 10.1', 'creator': 'PyPDF', 'creationdate': '2022-03-09T22:51:54-06:00', 'moddate': '2022-03-09T22:52:03-06:00', 'source': 'periodico.pdf', 'total_pages': 48, 'page': 24, 'page_label': '25'}

# %%
import ollama

# %%
response = ollama.chat(
    model='llama3.2-vision',
    messages=[{
        'role': 'user',
        'content': """Reorganize the following text to ensure it has semantic coherence and flows logically. MANTAIN the original meaning DO NOT add or remove text, ONLY reorganize it. The text is in Spanish, so please preserve the original language."""
    }, {
        'role': 'user',
        'content': specific_page.page_content
    }]
)

print(response)
# Out:
# model='llama3.2-vision' created_at='2025-04-24T17:56:04.6788872Z' done=True done_reason='stop' total_duration=95850479900 load_duration=40165200 prompt_eval_count=699 prompt_eval_duration=39365372600 eval_count=388 eval_duration=56425022800 message=Message(role='assistant', content='Aquí está el texto reorganizado para mantener su significado y fluir lógicamente:\n\nPA NA M Á\nPRÉSTAMOS Y DEPÓSITOS\nAUMENTARON EN 2021\n\nLa Superintendencia de Bancos de Panamá (SBP) informó que los nuevos préstamos totalizaron $16,844 millones en 2021, lo cual muestra una señal positiva de recuperación económica. Los préstamos nuevos y los depósitos de particulares en la banca panameña aumentaron un 14% y un 7.4%, respectivamente, en comparación con 2020.\n\nEste comportamiento positivo se dio en el contexto de la reactivación económica del país y la recuperación del producto interno bruto (PIB) en un 15.3% en el 2021, tras registrar en 2020 una caída del 17.9%.\n\nEl superintendente de bancos, Amauri Castillo, llamó a un "optimismo prudente" en materia económica y financiera, dada la presencia de "múltiples riesgos y un marco de fuerte incertidumbre, acrecentada por el conflicto en Ucrania".\n\nLos depósitos de particulares aumentaron $3,328 millones, lo que denota la confianza del depositante en el Sistema Bancario Nacional. El 60% de los depósitos pertenecen a empresas, con una tasa de crecimiento del 6.5%, mientras que el 40% restante corresponde a personas naturales, con alza de 3.8% respecto al 2021.\n\nAdemás, las cifras de la cartera modificada se redujeron en $13,681 millones.', images=None, tool_calls=None)

# %%
print(response.message.content)
# Out:
# Aquí está el texto reorganizado para mantener su significado y fluir lógicamente:
#
# PA NA M Á
# PRÉSTAMOS Y DEPÓSITOS
# AUMENTARON EN 2021
#
# La Superintendencia de Bancos de Panamá (SBP) informó que los nuevos préstamos totalizaron $16,844 millones en 2021, lo cual muestra una señal positiva de recuperación económica. Los préstamos nuevos y los depósitos de particulares en la banca panameña aumentaron un 14% y un 7.4%, respectivamente, en comparación con 2020.
#
# Este comportamiento positivo se dio en el contexto de la reactivación económica del país y la recuperación del producto interno bruto (PIB) en un 15.3% en el 2021, tras registrar en 2020 una caída del 17.9%.
#
# El superintendente de bancos, Amauri Castillo, llamó a un "optimismo prudente" en materia económica y financiera, dada la presencia de "múltiples riesgos y un marco de fuerte incertidumbre, acrecentada por el conflicto en Ucrania".
#
# Los depósitos de particulares aumentaron $3,328 millones, lo que denota la confianza del depositante en el Sistema Bancario Nacional. El 60% de los depósitos pertenecen a empresas, con una tasa de crecimiento del 6.5%, mientras que el 40% restante corresponde a personas naturales, con alza de 3.8% respecto al 2021.
#
# Además, las cifras de la cartera modificada se redujeron en $13,681 millones.

# %%
response = ollama.chat(
    model='llama3.2-vision',
    messages=[{
        'role': 'user',
        'content': """Separate the text into each news article, the output should be a JSON with each new containing Titular and content. DO NOT repeat news."""
    }, {
        'role': 'user',
        'content': response.message.content
    }]
)

# %%
print(response.message.content)
json_message = response.message.content
# Out:
# Aquí está el texto reorganizado en formato JSON, separado por noticia:
#
# ```json
# [
#   {
#     "titular": "Aumentaron préstamos y depósitos en 2021",
#     "contenido": "La Superintendencia de Bancos de Panamá (SBP) informó que los nuevos préstamos totalizaron $16,844 millones en 2021, lo cual muestra una señal positiva de recuperación económica. Los préstamos nuevos y los depósitos de particulares en la banca panameña aumentaron un 14% y un 7.4%, respectivamente, en comparación con 2020."
#   },
#   {
#     "titular": "Reactivación económica y recuperación del PIB",
#     "contenido": "Este comportamiento positivo se dio en el contexto de la reactivación económica del país y la recuperación del producto interno bruto (PIB) en un 15.3% en el 2021, tras registrar en 2020 una caída del 17.9%. El superintendente de bancos, Amauri Castillo, llamó a un 'optimismo prudente' en materia económica y financiera."
#   },
#   {
#     "titular": "Depósitos de particulares aumentaron",
#     "contenido": "Los depósitos de particulares aumentaron $3,328 millones, lo que denota la confianza del depositante en el Sistema Bancario Nacional. El 60% de los depósitos pertenecen a empresas, con una tasa de crecimiento del 6.5%, mientras que el 40% restante corresponde a personas naturales."
#   },
#   {
#     "titular": "Cartera modificada se redujo",
#     "contenido": "Además, las cifras de la cartera modificada se redujeron en $13,681 millones."
#   }
# ]
# ```
#
# Espero que esto sea lo que estabas buscando. ¡Si necesitas algo más, no dudes en preguntar!

# %%
start_char = "["
end_char = "]"

#Get AI response
message = json_message

#Clean AI Response
start_index = message.find(start_char)
end_index = message.find(end_char)+1
json_message = message[start_index:end_index]

print(json_message)
#print(message)
# Out:
# [
#   {
#     "titular": "Aumentaron préstamos y depósitos en 2021",
#     "contenido": "La Superintendencia de Bancos de Panamá (SBP) informó que los nuevos préstamos totalizaron $16,844 millones en 2021, lo cual muestra una señal positiva de recuperación económica. Los préstamos nuevos y los depósitos de particulares en la banca panameña aumentaron un 14% y un 7.4%, respectivamente, en comparación con 2020."
#   },
#   {
#     "titular": "Reactivación económica y recuperación del PIB",
#     "contenido": "Este comportamiento positivo se dio en el contexto de la reactivación económica del país y la recuperación del producto interno bruto (PIB) en un 15.3% en el 2021, tras registrar en 2020 una caída del 17.9%. El superintendente de bancos, Amauri Castillo, llamó a un 'optimismo prudente' en materia económica y financiera."
#   },
#   {
#     "titular": "Depósitos de particulares aumentaron",
#     "contenido": "Los depósitos de particulares aumentaron $3,328 millones, lo que denota la confianza del depositante en el Sistema Bancario Nacional. El 60% de los depósitos pertenecen a empresas, con una tasa de crecimiento del 6.5%, mientras que el 40% restante corresponde a personas naturales."
#   },
#   {
#     "titular": "Cartera modificada se redujo",
#     "contenido": "Además, las cifras de la cartera modificada se redujeron en $13,681 millones."
#   }
# ]

# %%
import fitz

def extract_first_page_text(pdf_path):
    doc = fitz.open(pdf_path)
    page = doc[26] 
    
    blocks = page.get_text("blocks") 
    sorted_blocks = sorted(blocks, key=lambda b: (b[1], b[0])) 
    
    page_text = "\n".join([block[4] for block in sorted_blocks]) 
    return page_text

pdf_text = extract_first_page_text("periodico.pdf")
print(pdf_text)
# Out:
# 27
# laprensagrafica.com Jueve s 10 de m a rzo de 2 02 2
# D e ptos @ L P G D ptos
#
# SANTA ANA
# DOS HOMBRES
# FA LL E C E N
# EN CHOQUE
# DE CAMIÓN
#
# A H UAC H A PA N
# SOLICITAN REIVINDICAR
# DERECHOS DE MUJERES
# Autoridades municipales y departamentales y líderes de
# comunidades, entre otros, participaron ayer en un evento
# organizado por la alcaldía de Apaneca, Ahuachapán, en el
# parque central de la localidad. Los expositores enfatizaron
# en reivindicar los derechos de las mujeres y pidieron
# justicia por el feminicidio de Fernanda Nájera, originaria de
# Apaneca, ocurrido hace más de tres años en Ataco.
# Marielos Román departamentos@laprensagrafica .com
#
# LPG /MARIELOS ROMÁN
#
# Impactaron contra un
# bus que se encontraba
# estacionado en la vía.
#
# Dos personas que se conducían a bordo
# de un camión fallecieron ayer en la madru-
# gada en un percance vial, informó la Cruz
# Verde de Santa Ana.
# El accidente sucedió en el kilómetro 73.5
# de la carretera que conduce de la cabecera
# departamental hacia el municipio de Cande-
# laria de La Frontera, en el cantón Comecayo,
# agregó el cuerpo de socorro.
# Las víctimas fueron identificadas como
# Cristóbal Pérez, de 52 años y David Ventura,
# de 27. Ambos viajaban en el camión placas
# P937 978 que colisionó contra un autobús de
# transporte de personal de maquilas par-
# queado a un costado de la carretera.
# Cruz Verde informó que fue necesario el
# uso de equipo hidráulico para extraer los ca-
# dáveres de la cabina del vehículo.
# Familiares de las víctimas explicaron que
# los dos hombres regresaban de trabajar.
# Miguel Marroquín
# d ep artame nto s@laprensagrafica .com
#
# SANTA ANA
# S uspenden
# juicio contra
# exa l c a l d e
#
# Miguel Marroquín
# d ep artame nto s@laprensagrafica .com
#
# l Juzgado Especializado de
# Sentencia parauna VidaLibre
# de Violencia para las Mujeres
# de Santa Ana suspendió ayer el inicio del
# juicio en contra del exalcalde de Santa
# Ana, José Orlando Mena Delgado, debido
# a que el imputado no se presentó a la sede
# judicial.
# Mena Delgado está acusado por los de-
# litos de violación en menor o incapaz en
# su modalidad continuada, otras agresio-
# nes sexuales y expresiones de violencia
# contra las mujeres donde la víctima al
# momento de los hechos era menor de
# edad, explicaron fuentes del Juzgado.
# Agregaron que el imputado no se pre-
# sentóa lavista públicaporque segúnuna
# constancia médica presentada por los
# abogados defensores,Mena seencontra-
# ba indispuesto de salud y presentaba sín-
# tomas similares al covid-19.
# Otras fuentes judiciales manifestaron
# que Mena Delgado había llegado el mar-
# tes al Juzgado para cumplir con la orden
# judicial de presentarse a firmar una vez
# por semana y no presentaba, en aparien-
# cia, ningún quebranto de salud.
# Lajueza deSentenciaordenó queMe-
# na Delgado se realizara un chequeo médi-
# co en la sede del Instituto de Medicina Le-
# gal y que se realizara una prueba rápida
# para la detección de coronavirus, dando
# un espaciode aproximadamentetres ho-
# ras, pero el imputado y abogados no cum-
# plieron la orden.
#
# E
#
# El exalcalde
# Orlando Mena
# no se presentó
# al Juzgado por
# supue sta
# i ncap ac id ad
# mé d ica .
#
# LPG /C ORTESÍA
#
# Pendiente. Mena no
# cumplió la orden de
# realizarse chequeo
# médico y prueba
# c ov i d -1 9.
#
# LPG /A RC H I VO
#
# La Policía dijo que la principal causa del
# percance vial fue la excesiva velocidad del camión.
#
# SAN MIGUEL
# ALCALDÍA ANUNCIA PLAN DE
# BACHEO EN ZONA URBANA
#
# C U S CAT L Á N
# MTP CONFIRMA MUERTE DE
# AGENTE POLICIAL EN EL ISSS
#
# El Movimiento de los Trabajadores de la Policía (MTP) confirmó la noche
# del martes el fallecimiento del agente Rodrigo Arnoldo Peña, ingresado en
# el Instituto Salvadoreño del Seguro Social (ISSS) desde el 5 de marzo, tras
# ser lesionado de bala en el municipio de Monte San Juan, Cuscatlán. Peña
# se encontraba destacado en la delegación de la PNC de San Vicente y fue
# atacado a balazos mientras se conducía en su motocicleta sobre el desvío
# al cantón Candelaria, calle al municipio de Monte San Juan, dijo el MTP.
# David Peña departamentos@laprensagrafica .com
#
# La alcaldía de San Miguel informó que ejecutarán un proyecto de
# mejoramiento de las calles de la zona urbana de la localidad. “P retendemos
# mejorar la mayor cantidad calles pues actualmente la DOM trabaja las que
# necesitan bacheo profundo y nosotros vamos a intervenir las restantes para
# abarcar una mayor cantidad”, dijo Mauricio Campos, secretario municipal.
# Dijo que intervendrán la zona sur de la ciudad, considerada como prioridad
# la colonia Milagro de La Paz, Santa Julia, El Tesoro y San Pablo.
# Emanuel Boquin departamentos@laprensagrafica .com

# %%
import ollama
response = ollama.chat(
    model='llama3.2-vision',
    messages=[{
        'role': 'user',
        'content': """Reorganize the following text to ensure it has semantic coherence and flows logically. MANTAIN the original meaning DO NOT add or remove text, ONLY reorganize it. The text is in Spanish, so please preserve the original language."""
    }, {
        'role': 'user',
        'content': specific_page.page_content
    }]
)

print(response)
# Out:
# model='llama3.2-vision' created_at='2025-04-03T22:53:52.2243937Z' done=True done_reason='stop' total_duration=193160348800 load_duration=15403320800 prompt_eval_count=1480 prompt_eval_duration=82502000000 eval_count=650 eval_duration=94462000000 message=Message(role='assistant', content='Aquí está el texto reorganizado para mantener su significado original y mejorar la coherencia lógica:\n\n**SANTA ANA**\n\n* Suspenden juicio contra exalcalde por violación de menor: El Juzgado Especializado de Sentencia para una Vida Libre de Violencia para las Mujeres de Santa Ana suspendió ayer el inicio del juicio en contra del exalcalde de Santa Ana, José Orlando Mena Delgado. Según fuentes judiciales, Mena no se presentó a la sede judicial debido a que según una constancia médica presentada por sus abogados, se encontraba indispuesto de salud y presentaba síntomas similares al covid-19.\n* Autoridades y líderes comunitarios reivindican derechos de las mujeres: El día anterior, en el parque central de Apaneca, Ahuachapán, autoridades municipales y departamentales, junto con líderes comunitarios y otros, participaron en un evento organizado por la alcaldía para reivindicar los derechos de las mujeres. También pidieron justicia por el feminicidio de Fernanda Nájera, ocurrido hace más de tres años.\n\n**SANTA ANA: DOS HOMBRES FALLECEN EN CHOQUE DE CAMIÓN**\n\n* Dos hombres fallecieron en un accidente vial: El día anterior, dos personas que se conducían a bordo de un camión fallecieron en un percance vial en el kilómetro 73.5 de la carretera que conduce de la cabecera departamental hacia el municipio de Candelaria de La Frontera.\n* La Policía atribuye el accidente a excesiva velocidad del camión: Según la Cruz Verde, la principal causa del percance vial fue la excesiva velocidad del camión.\n\n**CUSCATLÁN**\n\n* MTP confirma muerte de agente policial: El Movimiento de los Trabajadores de la Policía (MTP) confirmó el fallecimiento del agente Rodrigo Arnoldo Peña, ingresado en el Instituto Salvadoreño del Seguro Social (ISSS) desde el 5 de marzo.\n\n**SAN MIGUEL**\n\n* Alcaldía anuncia plan de bacheo en zona urbana: La alcaldía de San Miguel informó que ejecutarán un proyecto de mejoramiento de las calles de la zona urbana. "Pretenemos mejorar la mayor cantidad de calles pues actualmente la DOM trabaja las que necesitan bacheo profundo y nosotros vamos a intervenir las restantes para abarcar una", explicó.\n\n**OTROS**\n\n* Exalcalde no cumple orden de realizarse chequeo médico y prueba covid-19: El exalcalde de Santa Ana, José Orlando Mena Delgado, no cumplió con la orden judicial de presentarse a firmar una vez por semana ni realizar un chequeo médico en la sede del Instituto de Medicina Legal.', images=None, tool_calls=None)

# %%
response = ollama.chat(
    model='llama3.2-vision',
    messages=[{
        'role': 'user',
        'content': """Separate the text into each news article, the output should be a JSON with each new containing Titular and content. DO NOT repeat news."""
    }, {
        'role': 'user',
        'content': response.message.content
    }]
)

# %%
start_char = "["
end_char = "]"

#Get AI response
message = json_message

#Clean AI Response
start_index = message.find(start_char)
end_index = message.find(end_char)+1
json_message = message[start_index:end_index]

print(json_message)
#print(message)
# Out:
# [
#   {
#     "Titular": "**SANTA ANA**",
#     "Contenido": "* El Juzgado Especializado de Sentencia para una Vida Libre de Violencia para las Mujeres de Santa Ana suspendió ayer el inicio del juicio en contra del exalcalde de Santa Ana, José Orlando Mena Delgado.\n* Según fuentes judiciales, el imputado no se presentó a la vista pública porque según una constancia médica presentada por los abogados defensores, Mena se encontraba indispuesto de salud y presentaba síntomas similares al covid-19."
#   },
#   {
#     "Titular": "**DOS HOMBRES FALLECEN EN CHOQUE DE CAMIÓN**",
#     "Contenido": "* Dos personas que se conducían a bordo de un camión fallecieron ayer en la madrugada en un percance vial, informó la Cruz Verde de Santa Ana.\n* El accidente sucedió en el kilómetro 73.5 de la carretera que conduce de la cabecera departamental hacia el municipio de Candelaria de La Frontera, en el cantón Comecayo.\n* Las víctimas fueron identificadas como Cristóbal Pérez, de 52 años y David Ventura, de 27. Ambos viajaban en el camión placas P937978 que colisionó contra un autobús de transporte de personal de maquilas parqueado a un costado de la carretera."
#   },
#   {
#     "Titular": "**PENDIENTE**",
#     "Contenido": "* El exalcalde de Santa Ana, José Orlando Mena Delgado, no cumplió la orden de realizarse chequeo médico y prueba covid-19."
#   }
# ]
